# %%
# %matplotlib inline
import numpy as np
import matplotlib as plt
from qutip import *

# %%
def Energy_k(w,k1,k2,phi,t):
    delta1 = np.array([1,0])
    delta2 = np.array([1/2,-np.sqrt(3)/2])
    g1 = 4*np.pi/(np.sqrt(3))*np.array([1,0])
    g2 = 4*np.pi/(np.sqrt(3))*np.array([1/2,-np.sqrt(3)/2])
    k = k1*delta1 + k2*delta2
    alpha1 = np.inner(k,delta1)/2
    alpha2 = np.inner(k,delta2)/2
    alpha12 = alpha1 - alpha2
    H = Qobj([[w,2 * t * np.exp(1j * phi)*np.cos(alpha1),2 * t * np.exp(-1j * phi)*np.cos(alpha2)],
             [2 * t * np.exp(-1j * phi)*np.cos(alpha1),w,2 * t * np.exp(1j * phi)*np.cos(alpha12)],
              [2 * t * np.exp(1j * phi)*np.cos(alpha2),2 * t * np.exp(-1j * phi)*np.cos(alpha12),w]
             ])
    evals = H.eigenenergies()
    return (evals )

# %%
fig, ax = plt.pyplot.subplots()
step_k = 1000
k = np.linspace(-np.pi,np.pi,step_k)
step_k_2 = 20
k_2 = np.linspace(-10*np.pi,10*np.pi,step_k_2)
for u in k_2:
    result = []
    for i in k:
        result.append(Energy_k(1,i,u,0,1)-1)
    for j in range(3):
        ax.plot(k,[temp[j] for temp in result],'c')

# %%
fig, ax = plt.pyplot.subplots()
step_k = 1000
k = np.linspace(-np.pi,np.pi,step_k)
step_k_2 = 20
k_2 = np.linspace(-10*np.pi,10*np.pi,step_k_2)
for u in k_2:
    result = []
    for i in k:
        result.append(Energy_k(1,i,u,np.pi/6,1)-1)
    for j in range(3):
        ax.plot(k,[temp[j] for temp in result])

# %%
fig, ax = plt.pyplot.subplots()
step_k = 1000
k = np.linspace(-np.pi,np.pi,step_k)
step_k_2 = 20
k_2 = np.linspace(-10*np.pi,10*np.pi,step_k_2)
for u in k_2:
    result = []
    for i in k:
        result.append(Energy_k(1,i,u,np.pi/4,1)-1)
    for j in range(3):
        ax.plot(k,[temp[j] for temp in result])

# %%
fig, ax = plt.pyplot.subplots()
step_k = 1000
k = np.linspace(-np.pi,np.pi,step_k)
step_k_2 = 20
k_2 = np.linspace(-10*np.pi,10*np.pi,step_k_2)
for u in k_2:
    result = []
    for i in k:
        result.append(Energy_k(1,i,u,np.pi/3,1)-1)
    for j in range(3):
        ax.plot(k,[temp[j] for temp in result])

# %%
fig, ax = plt.pyplot.subplots()
step_k = 1000
k = np.linspace(-np.pi,np.pi,step_k)
step_k_2 = 20
k_2 = np.linspace(-10*np.pi,10*np.pi,step_k_2)
for u in k_2:
    result = []
    for i in k:
        result.append(Energy_k(1,i,u,np.pi/10,1)-1)
    for j in range(3):
        ax.plot(k,[temp[j] for temp in result])

# %%
fig, ax = plt.pyplot.subplots()
step_k = 1000
k = np.linspace(-np.pi,np.pi,step_k)
step_k_2 = 200
k_2 = np.linspace(-10*np.pi,10*np.pi,step_k_2)
for u in k_2:
    result = []
    for i in k:
        result.append(Energy_k(1,i,u,np.pi/100,1)-1)
    for j in range(3):
        ax.plot(k,[temp[j] for temp in result])
